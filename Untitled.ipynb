# %%
import pygro
import sympy as sp

# %%
metric = pygro.default_metrics.KerrBL(m = 1, a = 0.7)
# Out:
# Loading Kerr - Boyer-Lindquist
# The metric_engine has been initialized.

# %%
metric.x
# Out:
# [t, r, theta, phi]

# %%
G = 6.67e-11
c = 3e+8
M = 1e+6*2e+30

expr = "r > 2*G*M/c**2"

# %%
def set_stopping_criterion(self, expr):
    expr_s = sp.parse_expr(expr)
    free_symbols = list(expr_s.free_symbols-set(metric.x))
    for symbol in free_symbols:
        if str(symbol) in globals():
            print(globals()[str(symbol)])
            expr_s = expr_s.subs(symbol, globals()[str(symbol)])
        elif str(symbol) in locals():
            expr_s.subs(symbol, locals()[str(symbol)])
        else:
            raise TypeError("Unkwnown symbol {}".format(str(symbol)))
    self.stopping_criterion = sp.lambdify(self.metric.x, expr_s)

# %%
set_stopping_criterion(expr)
# Out:
# 300000000.0
# 6.67e-11
# 2e+36
# r > 2964444444.44444

# %%
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sympy as sp',
#   'import pygro',
#   'import pygro\nimport sympy as sp',
#   'metric = pygro.default_metrics.KerrBL(m = 1, a = 0.7)',
#   'metric.x',
#   'expr = "r > 2*G*M/c**2"',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'sp.parse_expr(expr)',
#   'expr_s = sp.parse_expr(expr)',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols()',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols[0] ',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   "expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols['G']",
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "print(\'cacca\')"',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'sp.parse_expr(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'sp.parse_expr(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2"',
#   'sp.lambdify(sp.parse_expr(expr))',
#   'sp.lambdify(sp.parse_expr(expr).free_symbols, sp.parse_expr(expr))',
#   'sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f(3)',
#   'f(1)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f(1)',
#   'list(sp.parse_expr(expr).free_symbols)',
#   'list(sp.parse_expr(expr).free_symbols)[2]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2])',
#   '__global__',
#   'globals()',
#   "globals('G')",
#   "globals()['G']",
#   'globals()[str(list(sp.parse_expr(expr).free_symbols)[2])]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) = globals()[]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[0]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[1]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[3]) in globals()',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x\n    return free_symbols',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    return free_symbols',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s.subs((symbol, globals()[str(symbol)]))\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Z*M/c**2"',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Gù*M/c**2"',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'locals()'],
#  '_oh': {5: [t, r, theta, phi],
#   8: r > 2*G*M/c**2,
#   11: {G, M, c, r},
#   13: {G, M, c, r},
#   15: {G, M, c, r},
#   17: {cacca},
#   18: print(cacca),
#   20: r > 2*G*M/c**2,
#   23: <function _lambdifygenerated(r)>,
#   24: <function _lambdifygenerated(r)>,
#   26: True,
#   27: False,
#   31: [c, G, M, r],
#   32: M,
#   33: 'M',
#   35: {...},
#   37: 6.67e-11,
#   38: 2e+36,
#   40: True,
#   41: True,
#   42: True,
#   43: True,
#   44: False,
#   49: [c, G, M],
#   51: r > 2*G*M/c**2,
#   53: r > 2*G*M/c**2,
#   57: r > 2964444444.44444,
#   59: r > 2964444444.44444,
#   62: r > 4.44444444444444e+19*Z,
#   68: r > 2964444444.44444},
#  '_dh': ['/Users/riccardodellamonica/Projects/pygro-base'],
#  'In': ['',
#   'import sympy as sp',
#   'import pygro',
#   'import pygro\nimport sympy as sp',
#   'metric = pygro.default_metrics.KerrBL(m = 1, a = 0.7)',
#   'metric.x',
#   'expr = "r > 2*G*M/c**2"',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'sp.parse_expr(expr)',
#   'expr_s = sp.parse_expr(expr)',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols()',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols[0] ',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   "expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols['G']",
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "print(\'cacca\')"',
#   'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#   'sp.parse_expr(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'sp.parse_expr(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2"',
#   'sp.lambdify(sp.parse_expr(expr))',
#   'sp.lambdify(sp.parse_expr(expr).free_symbols, sp.parse_expr(expr))',
#   'sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f(3)',
#   'f(1)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#   'f(1)',
#   'list(sp.parse_expr(expr).free_symbols)',
#   'list(sp.parse_expr(expr).free_symbols)[2]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2])',
#   '__global__',
#   'globals()',
#   "globals('G')",
#   "globals()['G']",
#   'globals()[str(list(sp.parse_expr(expr).free_symbols)[2])]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) = globals()[]',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[0]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[1]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#   'str(list(sp.parse_expr(expr).free_symbols)[3]) in globals()',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x\n    return free_symbols',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    return free_symbols',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s.subs((symbol, globals()[str(symbol)]))\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Z*M/c**2"',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Gù*M/c**2"',
#   'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#   'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#   'set_stopping_criterion(expr)',
#   'locals()'],
#  'Out': {5: [t, r, theta, phi],
#   8: r > 2*G*M/c**2,
#   11: {G, M, c, r},
#   13: {G, M, c, r},
#   15: {G, M, c, r},
#   17: {cacca},
#   18: print(cacca),
#   20: r > 2*G*M/c**2,
#   23: <function _lambdifygenerated(r)>,
#   24: <function _lambdifygenerated(r)>,
#   26: True,
#   27: False,
#   31: [c, G, M, r],
#   32: M,
#   33: 'M',
#   35: {...},
#   37: 6.67e-11,
#   38: 2e+36,
#   40: True,
#   41: True,
#   42: True,
#   43: True,
#   44: False,
#   49: [c, G, M],
#   51: r > 2*G*M/c**2,
#   53: r > 2*G*M/c**2,
#   57: r > 2964444444.44444,
#   59: r > 2964444444.44444,
#   62: r > 4.44444444444444e+19*Z,
#   68: r > 2964444444.44444},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10fba2430>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10fba2f40>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10fba2f40>,
#  '_': r > 2964444444.44444,
#  '__': r > 4.44444444444444e+19*Z,
#  '___': r > 2964444444.44444,
#  '_i': 'set_stopping_criterion(expr)',
#  '_ii': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_iii': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#  '_i1': 'import sympy as sp',
#  'sp': <module 'sympy' from '/usr/local/lib/python3.9/site-packages/sympy/__init__.py'>,
#  '_i2': 'import pygro',
#  'pygro': <module 'pygro' from '/Users/riccardodellamonica/Projects/pygro-base/pygro/__init__.py'>,
#  '_i3': 'import pygro\nimport sympy as sp',
#  '_i4': 'metric = pygro.default_metrics.KerrBL(m = 1, a = 0.7)',
#  'metric': <pygro.default_metrics.KerrBL.KerrBL at 0x17393a9d0>,
#  '_i5': 'metric.x',
#  '_5': [t, r, theta, phi],
#  '_i6': 'expr = "r > 2*G*M/c**2"',
#  'expr': 'r > 2*G*M/c**2',
#  '_i7': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#  'G': 6.67e-11,
#  'c': 300000000.0,
#  'M': 2e+36,
#  '_i8': 'sp.parse_expr(expr)',
#  '_8': r > 2*G*M/c**2,
#  '_i9': 'expr_s = sp.parse_expr(expr)',
#  'expr_s': print(cacca),
#  '_i10': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols()',
#  '_i11': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#  '_11': {G, M, c, r},
#  '_i12': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols[0] ',
#  '_i13': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#  '_13': {G, M, c, r},
#  '_i14': "expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols['G']",
#  '_i15': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#  '_15': {G, M, c, r},
#  '_i16': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "print(\'cacca\')"',
#  '_i17': 'expr_s = sp.parse_expr(expr)\nexpr_s.free_symbols',
#  '_17': {cacca},
#  '_i18': 'sp.parse_expr(expr)',
#  '_18': print(cacca),
#  '_i19': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#  '_i20': 'sp.parse_expr(expr)',
#  '_20': r > 2*G*M/c**2,
#  '_i21': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2"',
#  '_i22': 'sp.lambdify(sp.parse_expr(expr))',
#  '_i23': 'sp.lambdify(sp.parse_expr(expr).free_symbols, sp.parse_expr(expr))',
#  '_23': <function _lambdifygenerated(r)>,
#  '_i24': 'sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#  '_24': <function _lambdifygenerated(r)>,
#  '_i25': 'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#  'f': <function _lambdifygenerated(c, G, M, r)>,
#  '_i26': 'f(3)',
#  '_26': True,
#  '_i27': 'f(1)',
#  '_27': False,
#  '_i28': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#  '_i29': 'f = sp.lambdify(list(sp.parse_expr(expr).free_symbols), sp.parse_expr(expr))',
#  '_i30': 'f(1)',
#  '_i31': 'list(sp.parse_expr(expr).free_symbols)',
#  '_31': [c, G, M, r],
#  '_i32': 'list(sp.parse_expr(expr).free_symbols)[2]',
#  '_32': M,
#  '_i33': 'str(list(sp.parse_expr(expr).free_symbols)[2])',
#  '_33': 'M',
#  '_i34': '__global__',
#  '_i35': 'globals()',
#  '_35': {...},
#  '_i36': "globals('G')",
#  '_i37': "globals()['G']",
#  '_37': 6.67e-11,
#  '_i38': 'globals()[str(list(sp.parse_expr(expr).free_symbols)[2])]',
#  '_38': 2e+36,
#  '_i39': 'str(list(sp.parse_expr(expr).free_symbols)[2]) = globals()[]',
#  '_i40': 'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#  '_40': True,
#  '_i41': 'str(list(sp.parse_expr(expr).free_symbols)[0]) in globals()',
#  '_41': True,
#  '_i42': 'str(list(sp.parse_expr(expr).free_symbols)[1]) in globals()',
#  '_42': True,
#  '_i43': 'str(list(sp.parse_expr(expr).free_symbols)[2]) in globals()',
#  '_43': True,
#  '_i44': 'str(list(sp.parse_expr(expr).free_symbols)[3]) in globals()',
#  '_44': False,
#  '_i45': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x',
#  'set_stopping_criterion': <function __main__.set_stopping_criterion(expr)>,
#  '_i46': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols)-metric.x\n    return free_symbols',
#  '_i47': 'set_stopping_criterion(expr)',
#  '_i48': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    return free_symbols',
#  '_i49': 'set_stopping_criterion(expr)',
#  '_49': [c, G, M],
#  '_i50': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_i51': 'set_stopping_criterion(expr)',
#  '_51': r > 2*G*M/c**2,
#  '_i52': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#  '_i53': 'set_stopping_criterion(expr)',
#  '_53': r > 2*G*M/c**2,
#  '_i54': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s.subs((symbol, globals()[str(symbol)]))\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#  '_i55': 'set_stopping_criterion(expr)',
#  '_i56': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        \'\'\'elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\'\'\'\n    return expr_s',
#  '_i57': 'set_stopping_criterion(expr)',
#  '_57': r > 2964444444.44444,
#  '_i58': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_i59': 'set_stopping_criterion(expr)',
#  '_59': r > 2964444444.44444,
#  '_i60': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Z*M/c**2"',
#  '_i61': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            print("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_i62': 'set_stopping_criterion(expr)',
#  '_62': r > 4.44444444444444e+19*Z,
#  '_i63': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_i64': 'set_stopping_criterion(expr)',
#  '_i65': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*Gù*M/c**2"',
#  '_i66': 'G = 6.67e-11\nc = 3e+8\nM = 1e+6*2e+30\n\nexpr = "r > 2*G*M/c**2"',
#  '_i67': 'def set_stopping_criterion(expr):\n    expr_s = sp.parse_expr(expr)\n    free_symbols = list(expr_s.free_symbols-set(metric.x))\n    for symbol in free_symbols:\n        if str(symbol) in globals():\n            print(globals()[str(symbol)])\n            expr_s = expr_s.subs(symbol, globals()[str(symbol)])\n        elif str(symbol) in locals():\n            expr_s.subs(symbol, locals()[str(symbol)])\n        else:\n            raise TypeError("Unkwnown symbol {}".format(str(symbol)))\n    return expr_s',
#  '_i68': 'set_stopping_criterion(expr)',
#  '_68': r > 2964444444.44444,
#  '_i69': 'locals()'}
